# %% [markdown]
# ## Remove background the images when running the system.

# %%
import cv2
import matplotlib.pyplot as plt
from rembg import remove
from PIL import Image

# %%
# img = cv2.imread("32.jpg")
img = Image.open("32.jpg")
img1 = remove(img)

# %%
plt.figure(figsize=(20, 10))
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(img1)

# %%
img1.save("Image1.png")

# %% [markdown]
# ## detecte a object  in the images
