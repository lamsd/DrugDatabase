# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
#Read the two images
image1 = Image.open('Images/image_convert1_000024759_0.png')
image2 = Image.open('Images/image_convert1_00004-0800-85_SPLIMAGE30_491E24C1_2.png')

# %%
plt.figure(figsize=(20, 10))
plt.subplot(121)
plt.imshow(image1)
plt.subplot(122)
plt.imshow(image2)

# %%
image1 = image1.resize((426, 240))
image1_size = image1.size
image2_size = image2.size
new_image = Image.new('RGB',(2*image1_size[0], image1_size[1]), (250,250,250))
new_image.paste(image1,(0,0))
new_image.paste(image2,(image1_size[0],0))
new_image.save("merged_image.jpg","JPEG")

# %%
plt.figure(figsize=(20, 10))
plt.imshow(new_image)

# %%
from PIL import Image
  
img_01 = Image.open("Images/image_convert1_000024759_0.png")
img_02 = Image.open("Images/image_convert1_00004-0800-85_SPLIMAGE30_491E24C1_2.png")
img_03 = Image.open("Images/image_convert1_000390223_PB_2.png")
img_04 = Image.open("Images/image_convert1_00054-4550-25_SPLIMAGE30_F408FA07_2.png")
img_05 = Image.open("Images/image_convert1_000780073_1.png")
img_06 = Image.open("Images/image_convert1_604290566_1.png")
img_07 = Image.open("Images/image_convert1_pill25522-1_2.png")
img_08 = Image.open("Images/image_convert2_615700024_0.png")
img_09 = Image.open("Images/image_convert2_Oval_007815949_0.png")
img_10 = Image.open("Images/image_convert2_t101840f_2.png")
  
img_01_size = img_01.size
img_02_size = img_02.size
img_03_size = img_02.size
img_02_size = img_02.size
  
print('img 1 size: ', img_01_size)
print('img 2 size: ', img_02_size)
print('img 3 size: ', img_03_size)
print('img 4 size: ', img_03_size)
  
new_im = Image.new('RGB', (img_01_size[0]*5,img_01_size[1]*2), (250,250,250))
  
new_im.paste(img_01, (img_01_size[0]*0,img_01_size[1]*0))
new_im.paste(img_02, (img_01_size[0]*1,img_01_size[1]*0))
new_im.paste(img_03, (img_01_size[0]*2,img_01_size[1]*0))
new_im.paste(img_04, (img_01_size[0]*3,img_01_size[1]*0))
new_im.paste(img_05, (img_01_size[0]*4,img_01_size[1]*0))
new_im.paste(img_06, (img_01_size[0]*0,img_01_size[1]*1))
new_im.paste(img_07, (img_01_size[0]*1,img_01_size[1]*1))
new_im.paste(img_08, (img_01_size[0]*2,img_01_size[1]*1))
new_im.paste(img_09, (img_01_size[0]*3,img_01_size[1]*1))
new_im.paste(img_10, (img_01_size[0]*4,img_01_size[1]*1))
new_im = new_im.resize((640, 480))  
new_im.save("merged_images.png", "PNG")
new_im.show()
# Out:
# img 1 size:  (600, 501)
# img 2 size:  (600, 501)
# img 3 size:  (600, 501)
# img 4 size:  (600, 501)
